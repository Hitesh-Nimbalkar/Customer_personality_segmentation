# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\Projects\Consumer_prediction\data_modified.csv")

# %%
df.columns
# Out:
# Index(['Education', 'Income', 'Recency', 'Wines', 'Fruits', 'Meat', 'Fish',
#        'Sweets', 'Gold', 'NumDealsPurchases', 'Complain', 'Total_Offsprings',
#        'Living_With', 'Family_Size', 'Days_since_enrollment', 'Age',
#        'Total_products', 'Frequency', 'Total_purchases'],
#       dtype='object')

# %%
df.head()
# Out:
#    Education   Income  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  \
# 0          3  58138.0       58    635      88   546   172      88    88
# 1          3  46344.0       38     11       1     6     2       1     6
# 2          3  71613.0       26    426      49   127   111      21    42
# 3          3  26646.0       26     11       4    20    10       3     5
# 4          2  58293.0       94    173      43   118    46      27    15
#
#    NumDealsPurchases  Complain  Total_Offsprings  Living_With  Family_Size  \
# 0                  3         0                 0            0            1
# 1                  2         0                 2            0            3
# 2                  1         0                 0            1            2
# 3                  2         0                 1            1            3
# 4                  5         0                 1            1            3
#
#    Days_since_enrollment  Age  Total_products  Frequency  Total_purchases
# 0                    663   66            1617          6               22
# 1                    113   69              27          0                4
# 2                    312   58             776          0               20
# 3                    139   39              53          0                6
# 4                    161   42             422          0               14

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Postgraduate', 'Undergraduate'], dtype=object)

# %%
def get_numerical_columns(data_frame):
    numerical_columns = []
    for column in data_frame.columns:
        if pd.api.types.is_numeric_dtype(data_frame[column]):
            numerical_columns.append(column)
    return numerical_columns

numerical_columns=get_numerical_columns(df)

# %%
numerical_columns
# Out:
# ['Income',
#  'Recency',
#  'Wines',
#  'Fruits',
#  'Meat',
#  'Fish',
#  'Sweets',
#  'Gold',
#  'NumDealsPurchases',
#  'Complain',
#  'Total_Offsprings',
#  'Family_Size',
#  'Days_since_enrollment',
#  'Age',
#  'Total_products',
#  'Frequency',
#  'Total_purchases']

# %%
df.dtypes
# Out:
# Education                  int64
# Income                   float64
# Recency                    int64
# Wines                      int64
# Fruits                     int64
# Meat                       int64
# Fish                       int64
# Sweets                     int64
# Gold                       int64
# NumDealsPurchases          int64
# Complain                   int64
# Total_Offsprings           int64
# Living_With                int64
# Family_Size                int64
# Days_since_enrollment      int64
# Age                        int64
# Total_products             int64
# Frequency                  int64
# Total_purchases            int64
# dtype: object
