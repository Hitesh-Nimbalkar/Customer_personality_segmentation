# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\Projects\Consumer_prediction\df_selected.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Education', 'Income', 'Recency', 'Wines', 'Fruits',
#        'Meat', 'Fish', 'Sweets', 'Gold', 'NumDealsPurchases', 'Complain',
#        'Total_Offsprings', 'Living_With', 'Family_Size',
#        'Days_since_enrollment', 'Age', 'Total_Amount', 'Frequency',
#        'Total_purchases', 'cluster', 'ID'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  Education    Income   Recency     Wines    Fruits      Meat  \
# 0           0   3.228958  2.621012  2.644521  3.312187  3.883381  4.024122
# 1           1   3.228958  2.073001  1.953509  1.462033  1.697070  1.616212
# 2           2   3.228958  3.247131  1.538902  2.692504  2.903310  2.155762
# 3           3   3.228958  1.157728  1.538902  1.462033  1.772460  1.678639
# 4           4   1.765569  2.628214  3.888342  1.942361  2.752530  2.115630
#
#        Fish    Sweets      Gold  ...  Total_Offsprings  Living_With  \
# 0  4.788339  3.818748  3.184041  ...          1.069920     0.986051
# 1  1.683229  1.700327  1.601364  ...          3.739929     0.986051
# 2  3.674153  2.187320  2.296198  ...          1.069920     3.076051
# 3  1.829352  1.749026  1.582063  ...          2.404925     3.076051
# 4  2.486905  2.333418  1.775073  ...          2.404925     3.076051
#
#    Family_Size  Days_since_enrollment       Age  Total_Amount  Frequency  \
# 0     0.576254               3.863289  3.320424      4.009419   3.449016
# 1     2.784539               1.146341  3.570751      1.371681   1.827435
# 2     1.680397               2.129383  2.652883      2.614238   1.827435
# 3     2.784539               1.274779  1.067475      1.414813   1.827435
# 4     2.784539               1.383457  1.317802      2.026968   1.827435
#
#    Total_purchases  cluster    ID
# 0         3.644881        0  5524
# 1         1.146145        1  2174
# 2         3.367243        0  4141
# 3         1.423782        1  6182
# 4         2.534332        1  5324
#
# [5 rows x 22 columns]

# %%
df['Education'].unique()
# Out:
# array([nan])

# %%
def get_numerical_columns(data_frame):
    numerical_columns = []
    for column in data_frame.columns:
        if pd.api.types.is_numeric_dtype(data_frame[column]):
            numerical_columns.append(column)
    return numerical_columns

numerical_columns=get_numerical_columns(df)

# %%
numerical_columns
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Education',
#  'Income',
#  'Recency',
#  'Wines',
#  'Fruits',
#  'Meat',
#  'Fish',
#  'Sweets',
#  'Gold',
#  'NumDealsPurchases',
#  'Complain',
#  'Total_Offsprings',
#  'Living_With',
#  'Family_Size',
#  'Days_since_enrollment',
#  'Age',
#  'Total_Amount',
#  'Frequency',
#  'Total_purchases',
#  'cluster']

# %%
df.dtypes
# Out:
# Education                  int64
# Income                   float64
# Recency                    int64
# Wines                      int64
# Fruits                     int64
# Meat                       int64
# Fish                       int64
# Sweets                     int64
# Gold                       int64
# NumDealsPurchases          int64
# Complain                   int64
# Total_Offsprings           int64
# Living_With                int64
# Family_Size                int64
# Days_since_enrollment      int64
# Age                        int64
# Total_products             int64
# Frequency                  int64
# Total_purchases            int64
# dtype: object
